# %% [markdown]
# # Del 2, får använda luntlapp
#
# Lämna in provet genom att spara ipynb-filerna och skicka dem till oskar.lappi@turku.fi
#
# ## Uppgift 1
#
#
# Skriv en funktion ```är_positiv``` som kollar ifall ett tal är positivt (använd t.ex. if-sats). Funktionen **returnerar** värdet ```True``` om talet är positivt, ```False``` om talet är negativt eller 0

# %%
#Uppgift 1a

# %% [markdown]
# ## Uppgift 2
#
# Skriv en klass som heter ```Datum``` som består av följande värden:
#
#   - ```år```
#   - ```månad```
#   - ```dag```
#
#   och följande funktioner:
#
#   - ```__init__```
#   - ```to_string```
#
# ```__init__``` ska ta in alla tre värden, och ```to_string``` ska **returnera** datumet i formen dag.månad.år

# %%
#Uppgift 2

# %% [markdown]
# ## Uppgift 3
#
# I cellen nedan har några ```Djur``` sparats i en lista ```djur```. Skriv en kodsnutt eller funktion som räknar ut hur många får som finns bland djuren.
#
# Tips: använd en får-loop

# %%
#Uppgift 3

class Djur:
    pass
    
class Får(Djur):
    art="Får"
    
class Varg(Djur):
    art="Varg"
    
djur=[Får(),Får(),Får(),Får(),Varg(),Får(),Får(),Får(),Varg(),Får(),Får(),Får(),Får(),Får(),Får(),Får(),
     Får(),Får(),Får(),Får(),Får(),Varg(),Får(),Får(),Får(),Får(),Får(),Får(),Får(),Får(),Varg(),Får()]

# %% [markdown]
# ### Luntlappen är infogad här under, med den går också att se från:
#
# https://github.com/oj-lappi/python-cheat-sheet

# %%
import requests
from IPython.display import Markdown 
Markdown(requests.get("https://raw.githubusercontent.com/oj-lappi/python-cheat-sheet/master/README.md").text)
# Out:
# # Variabler
#
# Variabler är behållare som innehåller värden
#
# I python är allt som inte är ett nyckelord och är utan ""-tecken en variabel
#
# Vi initialiserar (skapar) variabler genom tilldelningsoperatorn =
#
#
#
# ```python
# #Tilldelningsoperatorn =
# #Tilldelar (sparar) värdet på höger sida in i variabeln (behållaren) på vänster sida
# #Om variabeln inte finns, skapas den nu
#
# #Värdet på höger sida kan vara variabel eller ett bokstavligt värde
#
# #Ex.
#
# tal = 1
#
# namn = "kalle"
#
# inköpslista = ["äppel","banan"]
#
# #Om vi vill skapa en tom variabel använder vi ett passande "tomt" värde på höger sida
#
# #Ex
#
# tal = 0        #0 kan vara passande "tomt" värde för tal
#
# efternamn = "" #Tom sträng (tom text) är passande för textdata
#
# objekt = None  #Specialvärde som python-skaparna har bestämt att betyder "inget"
#
# todo_list = [] # Tom lista
#
#
# ```
#
#
# ```python
# #Datatyper
#
# #Det finns några olika typer av data i python
# ...
